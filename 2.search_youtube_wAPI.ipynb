# %% [markdown]
# ### Program to search YouTube using its API
# ###### (by Valentin Todorov - 08/28/2017)
# This program was developed to scrub all videos from Suzanita & Kaskata in which "Allahumma Ya Subuhun" can be heard in the background.

# %%
# Import the libraries that will be used in the program
import pandas as pd
import requests
import json
import time
import re
from datetime import datetime

# My API key from YouTube
api_key = "AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4"

# Set the parameters for the number of search pages to return, the number of records per search page and the location of the final Excel file
search_pages = 20
search_results_per_page = 50
final_output_location = "/Users/valentin/Google Drive/VideoSearch"


# Initialize empty lists for the data I'll be collecting - videos' links, titles, uploader, channel, and date uploaded on
video_link = []
video_title = []
video_user = []
video_user_channel = []
video_publish_date = []
search_term_used = []


# Search terms: suzanita+lucifer; suzanita+kaskata; lucifer+buddha; луцифер+буда; сузанита+луцифер; сузанита+каската; biz+amulet;
# Define the parameters
# For search terms in Bulgarian only -->>  (1) In "search_term" write the search in Bulgarian, and (2) in "search_term_save" write the search in English
search_term = ["suzanita+lucifer", "suzanita+kaskata", "lucifer+buddha", "biz+amulet", "сузанита+луцифер", "сузанита+каската"]
search_term_save = ["suzanita+lucifer", "suzanita+kaskata", "lucifer+buddha", "biz+amulet", "suzanita+lucifer_inBulgarian", "suzanita+kaskata_inBulgarian"]


for s in range(len(search_term)):
    
    # Create an empty token value for the first page - Each search page returned has a token
    # To go to the next page with results we need to add the token value to the end of the url
    # The token value will be updated from the JSON file which is returned in the API call
    next_page_token = ""

    print ("\nBeginning the search for: " + search_term_save[s])
    time.sleep(1)

    # Loop through the first n pages of search results
    for page_results in range(1, (search_pages + 1)):

        # API call and JSON response
        search_url = ("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=" + str(search_results_per_page) + "&q=" + search_term[s] + "&key=" + api_key + "&pageToken=" + next_page_token)
        api_response = requests.get(url = search_url)
        json_data = json.loads(api_response.text)

        if page_results == 1:
            print ("The program will collect the information from the first " + str(search_pages * search_results_per_page) + " videos returned in the search")
            time.sleep(1)
            print ("The total number of videos found on YouTube for the search term " + search_term[s] + " are: " + str(json_data['pageInfo']['totalResults']))

        # Update the token for the next page with search results
        next_page_token = str(json_data['nextPageToken'])

        print ("Extracting content from page: " + str(page_results))
        print ("The next page token is: " + str(next_page_token))
        print search_url

        # Loop through all the search results returned in the API
        for videos in range(1, len(json_data['items'])):

            # Get the link to video
            video_link.append("https://www.youtube.com/watch?v=" + json_data['items'][videos]['id'].values()[1])

            # Get title of video
            video_title.append(json_data['items'][videos]['snippet']['title'])

            # Get the user name/channel name from which a video was uploaded
            video_user.append(json_data['items'][videos]['snippet']['channelTitle'])

            # Get link to the channel
            video_user_channel.append("https://www.youtube.com/channel/" + json_data['items'][videos]['snippet']['channelId'])

            # Date of video upload. The extract date is a string, from which the data is extracted
            # Example from here: https://stackoverflow.com/questions/37192942/extract-date-from-string-in-python
            string_date = str(json_data['items'][videos]['snippet']['publishedAt'])
            match = re.search(r'\d{4}-\d{2}-\d{2}', string_date)
            date = datetime.strptime(match.group(), '%Y-%m-%d').date()
            video_publish_date.append(date)


        # WORK ON THIS!! - For some reason if I add the search term used, I get an encoding error
        # Add the search term that was used
        search_term_used.append(search_term_save[s])

        
## Create a dataframe with the video links, titles, username and number of views
print ("\nStack the information about videos in a Pandas dataframe")
time.sleep(1)

final_combined_df = pd.DataFrame(list(zip(video_link, video_title, video_user, video_user_channel, video_publish_date, search_term_used)),
                                 columns = ['video_link', 'video_title', 'video_user', 'video_user_channel', 'video_publish_date', 'search_term_used'])
final_combined_df.head(10)


############################################
#######  Add functionalities
############################################

# Dedup the dataframe by video_link
# YouTube returns the same video in the search results when using different search terms)
final_combined_df2 = final_combined_df.drop_duplicates(subset = ['video_link'], keep = False)


# Remove rows where len(video_link) > 43. Playlists and channels have a url length greater than 43
# These can also be removed through the API -> (json_data['items'][tt]['id'].values()[0] == "youtube#video")
final_combined_df2 = final_combined_df2[final_combined_df2['video_link'].map(len) < 44]


# WORK ON THIS -- Create a flag which videos to keep - use the logic I created in Excel
# The videos with the flag are more likely to include Allahumma Ya Subuhun in the background



## Write to an Excel file on Google Drive
print ("\nWrite file to Excel on Google Drive\n The location is: "  + final_output_location + "/videos_links_final_" + time.strftime("%Y%m%d") + ".xlsx")

writer_excel = pd.ExcelWriter(final_output_location + "/videos_links_final_" + time.strftime("%Y%m%d") + ".xlsx")
final_combined_df2.to_excel(writer_excel, 'Sheet1')
writer_excel.save()

print ("\nComplete!\nFile successfully written to Google Drive")
# Out:
# Beginning the search for: suzanita+lucifer
# The program will collect the information from the first 500 videos returned in the search
# The total number of videos found on YouTube for the search term suzanita+lucifer are: 2226
# Extracting content from page: 1
# The next page token is: CDIQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=
# Extracting content from page: 2
# The next page token is: CGQQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CDIQAA
# Extracting content from page: 3
# The next page token is: CJYBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CGQQAA
# Extracting content from page: 4
# The next page token is: CMgBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJYBEAA
# Extracting content from page: 5
# The next page token is: CPoBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMgBEAA
# Extracting content from page: 6
# The next page token is: CKwCEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CPoBEAA
# Extracting content from page: 7
# The next page token is: CN4CEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CKwCEAA
# Extracting content from page: 8
# The next page token is: CJADEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CN4CEAA
# Extracting content from page: 9
# The next page token is: CMIDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJADEAA
# Extracting content from page: 10
# The next page token is: CPQDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+lucifer&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMIDEAA
#
# Beginning the search for: suzanita+kaskata
# The program will collect the information from the first 500 videos returned in the search
# The total number of videos found on YouTube for the search term suzanita+kaskata are: 2302
# Extracting content from page: 1
# The next page token is: CDIQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=
# Extracting content from page: 2
# The next page token is: CGQQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CDIQAA
# Extracting content from page: 3
# The next page token is: CJYBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CGQQAA
# Extracting content from page: 4
# The next page token is: CMgBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJYBEAA
# Extracting content from page: 5
# The next page token is: CPoBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMgBEAA
# Extracting content from page: 6
# The next page token is: CKwCEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CPoBEAA
# Extracting content from page: 7
# The next page token is: CN4CEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CKwCEAA
# Extracting content from page: 8
# The next page token is: CJADEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CN4CEAA
# Extracting content from page: 9
# The next page token is: CMIDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJADEAA
# Extracting content from page: 10
# The next page token is: CPQDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=suzanita+kaskata&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMIDEAA
#
# Beginning the search for: lucifer+buddha
# The program will collect the information from the first 500 videos returned in the search
# The total number of videos found on YouTube for the search term lucifer+buddha are: 130188
# Extracting content from page: 1
# The next page token is: CDIQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=
# Extracting content from page: 2
# The next page token is: CGQQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CDIQAA
# Extracting content from page: 3
# The next page token is: CJYBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CGQQAA
# Extracting content from page: 4
# The next page token is: CMgBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJYBEAA
# Extracting content from page: 5
# The next page token is: CPoBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMgBEAA
# Extracting content from page: 6
# The next page token is: CKwCEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CPoBEAA
# Extracting content from page: 7
# The next page token is: CN4CEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CKwCEAA
# Extracting content from page: 8
# The next page token is: CJADEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CN4CEAA
# Extracting content from page: 9
# The next page token is: CMIDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJADEAA
# Extracting content from page: 10
# The next page token is: CPQDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=lucifer+buddha&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMIDEAA
#
# Beginning the search for: biz+amulet
# The program will collect the information from the first 500 videos returned in the search
# The total number of videos found on YouTube for the search term biz+amulet are: 45401
# Extracting content from page: 1
# The next page token is: CDIQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=
# Extracting content from page: 2
# The next page token is: CGQQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CDIQAA
# Extracting content from page: 3
# The next page token is: CJYBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CGQQAA
# Extracting content from page: 4
# The next page token is: CMgBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJYBEAA
# Extracting content from page: 5
# The next page token is: CPoBEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMgBEAA
# Extracting content from page: 6
# The next page token is: CKwCEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CPoBEAA
# Extracting content from page: 7
# The next page token is: CN4CEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CKwCEAA
# Extracting content from page: 8
# The next page token is: CJADEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CN4CEAA
# Extracting content from page: 9
# The next page token is: CMIDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CJADEAA
# Extracting content from page: 10
# The next page token is: CPQDEAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=biz+amulet&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=CMIDEAA
#
# Beginning the search for: suzanita+lucifer_inBulgarian
# The program will collect the information from the first 500 videos returned in the search
# The total number of videos found on YouTube for the search term сузанита+луцифер are: 1547
# Extracting content from page: 1
# The next page token is: CDIQAA
# https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=50&q=сузанита+луцифер&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4&pageToken=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-196636f054e6> in <module>()
#      47         # API call and JSON response
#      48         search_url = ("https://www.googleapis.com/youtube/v3/search?part=snippet&maxResults=" + str(search_results_per_page) + "&q=" + search_term[s] + "&key=" + api_key + "&pageToken=" + next_page_token)
# ---> 49         api_response = requests.get(url = search_url)
#      50         json_data = json.loads(api_response.text)
#      51
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     377         try:
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/requests/packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     253     def recv(self, *args, **kwargs):
#     254         try:
# --> 255             data = self.connection.recv(*args, **kwargs)
#     256         except OpenSSL.SSL.SysCallError as e:
#     257             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/valentin/anaconda/envs/py27/lib/python2.7/site-packages/OpenSSL/SSL.pyc in recv(self, bufsiz, flags)
#    1513             result = _lib.SSL_peek(self._ssl, buf, bufsiz)
#    1514         else:
# -> 1515             result = _lib.SSL_read(self._ssl, buf, bufsiz)
#    1516         self._raise_ssl_error(self._ssl, result)
#    1517         return _ffi.buffer(buf, result)[:]
#
# KeyboardInterrupt:

# %%
df
# Out:
#        A  B  C
# 0  fooba  0  A
# 1  foora  1  A
# 2     fo  1  B
# 3    bar  1  A

# %%
df_dedup
# Out:
#        A  B  C  D
# 0  fooba  0  A  4
# 1  foora  1  A  4
# 2     fo  1  B  4
# 3    bar  1  A  4

# %%
df[df['A'].map(len) < 4]
# Out:
#      A  B  C
# 2   fo  1  B
# 3  bar  1  A
