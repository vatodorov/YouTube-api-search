# %%
import pandas as pd
import requests
import json
import time


api_key = "AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4"
final_output_location = "/Users/valentin/Google Drive/VideoSearch"
video_removed = "VIDEO HAS BEEN REMOVED"
video_still_available = "VIDEO IS STILL AVAILABLE"

# Extract today's date
today_date = time.strftime("%d/%m/%Y")


# Read the XLS file with the links Bijan sent to YouTube
videos_sent = pd.read_excel(final_output_location + "/videos_links_final_send.xlsx")
vids_not_removed = videos_sent['video_removed'].tolist()
vids_sent_list = videos_sent['video_link']


# Create empty lists
video_test_exist_title = []
video_test_exist_flag = []
video_test_exist_date = []
video_test_exist_link = []


# Loop through all videos in the file I sent to Bijan
for i in range(len(vids_sent_list)):
    
    # This condition is True if a video is still available on YouTube
    if vids_not_removed[i] == "VIDEO IS STILL AVAILABLE":
        videoid_test = vids_sent_list[i].split("watch?v=")[1]
        
        search_url = ("https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=" + videoid_test + "&key=" + api_key)
        print i, vids_sent_list[i]
        
        api_response = requests.get(url = search_url)
        json_data = json.loads(api_response.text)
    
    # Test if a video is still available
    # -> If removed, record today's date, and put as title "VIDEO HAS BEEN REMOVED"
    # -> If video is still available, record the title, and leave the date empty
        try:
            video_test_exist_title.append(json_data['items'][0]['snippet']['title'])
            video_test_exist_flag.append(video_still_available)
            video_test_exist_date.append(today_date)
            video_test_exist_link.append(vids_sent_list[i])
            
        except:
            video_test_exist_title.append(video_removed)
            video_test_exist_flag.append(video_removed)
            video_test_exist_date.append(today_date)
            video_test_exist_link.append(vids_sent_list[i])
            
    elif vids_not_removed[i] == "VIDEO HAS BEEN REMOVED":
            video_test_exist_title.append(video_removed)
            video_test_exist_flag.append(video_removed)
            video_test_exist_date.append(today_date)
            video_test_exist_link.append(vids_sent_list[i])
        
    # This condition should never be True (!!). If it's True, something is wrong with the algorithm. 
    else:
        video_test_exist_title.append("ERROR: CHECK YOUR ALGORITHM")
        video_test_exist_flag.append("ERROR: CHECK YOUR ALGORITHM")
        video_test_exist_date.append(7777)


# Combine the lists into a dataframe        
## Create a dataframe with the video links, titles, username and number of views
print ("\nStack the information from the tests in a Pandas dataframe")
time.sleep(1)

video_test_df = pd.DataFrame(list(zip(video_test_exist_link, video_test_exist_title, video_test_exist_flag, video_test_exist_date)),
                                 columns = ['video_test_exist_link', 'video_test_exist_title', 'video_test_exist_flag', 'video_test_exist_date'])


## Write the file with the tests to Google Drive
print ("\nWrite file to Excel on Google Drive\n The location is: "  + final_output_location + "/video_test_exist_" + time.strftime("%Y%m%d") + ".xlsx")

write_video_test_excel = pd.ExcelWriter(final_output_location + "/video_test_exist_" + time.strftime("%Y%m%d") + ".xlsx")
video_test_df.to_excel(write_video_test_excel, 'Sheet1')
write_video_test_excel.save()



## Merge the video links test file with the main list with links to send
# Keep the values in all columns from the old file, except for:
#    -> date_video_last_found_youtube - update only the date of the videos which have been removed since the prior test
#    -> video_removed - change this flag to "Video Has Been Removed" only for the videos removed since the prior test




## Write the final file to Google Drive
# Out:
# 0 https://www.youtube.com/watch?v=8tiXrZ9G0RY
# 1 https://www.youtube.com/watch?v=lCEA6mOrURE
# 2 https://www.youtube.com/watch?v=S0_ext7fEDE
# 3 https://www.youtube.com/watch?v=aiB7fKb82jA
# 4 https://www.youtube.com/watch?v=XsX4W_sjxCY
# 6 https://www.youtube.com/watch?v=R4AnQxW3_98
# 7 https://www.youtube.com/watch?v=dqHrudTG0Fc
# 8 https://www.youtube.com/watch?v=bJlTojvcktg
# 10 https://www.youtube.com/watch?v=-TQfZHa-0Tw
# 11 https://www.youtube.com/watch?v=bH8L6FFIHhw
# 12 https://www.youtube.com/watch?v=QMaXGQjTEwE
# 13 https://www.youtube.com/watch?v=VV0wo8Fkc0I
# 14 https://www.youtube.com/watch?v=hoj_dKOmvWM
# 15 https://www.youtube.com/watch?v=GBmOWd5B9Gc
# 16 https://www.youtube.com/watch?v=Bcwi_xvxQsA
# 18 https://www.youtube.com/watch?v=LfFAQtsHo84
# 19 https://www.youtube.com/watch?v=3qhmElblIgg
# 20 https://www.youtube.com/watch?v=5-Ev7nKYLfI
# 22 https://www.youtube.com/watch?v=_FmPYCQqiks
# 23 https://www.youtube.com/watch?v=TpdYI_faS94
# 24 https://www.youtube.com/watch?v=J_dDUTMwcRs
# 25 https://www.youtube.com/watch?v=yAvvx6b5GyY
# 26 https://www.youtube.com/watch?v=OhIxkJv07DI
# 27 https://www.youtube.com/watch?v=L8d_aZdZWvI
# 28 https://www.youtube.com/watch?v=ARX4MKrsIL8
# 29 https://www.youtube.com/watch?v=dH2vHKYWFHM
# 30 https://www.youtube.com/watch?v=WKsjzeHc8dc
# 31 https://www.youtube.com/watch?v=iWJPhSJd9wc
# 32 https://www.youtube.com/watch?v=ZiieeVLQ7qo
# 33 https://www.youtube.com/watch?v=Bu5mBZHgk3Y
# 34 https://www.youtube.com/watch?v=rFetGofKhe0
# 35 https://www.youtube.com/watch?v=PLpKcjWybxQ
# 37 https://www.youtube.com/watch?v=mSU7SoIoU9g
# 38 https://www.youtube.com/watch?v=RVQrIM7__jY
# 39 https://www.youtube.com/watch?v=xfJ7vISQmlg
# 41 https://www.youtube.com/watch?v=vtGqq5T_sW8
# 42 https://www.youtube.com/watch?v=z27yyervs8o
# 43 https://www.youtube.com/watch?v=mH0b8MCoq-A
# 44 https://www.youtube.com/watch?v=vcs5N95bio4
# 45 https://www.youtube.com/watch?v=m7dflDKd9m8
# 46 https://www.youtube.com/watch?v=YUoeS8pV_Wg
# 47 https://www.youtube.com/watch?v=r6EGlypj9rA
# 48 https://www.youtube.com/watch?v=AE-xGj4M6nw
# 49 https://www.youtube.com/watch?v=uEWXrB815jQ
# 50 https://www.youtube.com/watch?v=RZSqslcfrk0
# 51 https://www.youtube.com/watch?v=snTY4rSod_I
# 52 https://www.youtube.com/watch?v=3-u9y5da-es
# 53 https://www.youtube.com/watch?v=3VZyJ_PAg88
# 54 https://www.youtube.com/watch?v=xpuj_yLAd8E
# 55 https://www.youtube.com/watch?v=dYAHoAM4U1Q
# 56 https://www.youtube.com/watch?v=iBmemj6T7tg
# 57 https://www.youtube.com/watch?v=SHtusudESCM
# 58 https://www.youtube.com/watch?v=t6u_XI76uTA
# 59 https://www.youtube.com/watch?v=gkZlO-F1B08
# 60 https://www.youtube.com/watch?v=KfF6iSljo0g
# 61 https://www.youtube.com/watch?v=LDr7d4VJhAw
# 62 https://www.youtube.com/watch?v=ESyFdgpv55U
# 63 https://www.youtube.com/watch?v=NmThfFShLzs
# 64 https://www.youtube.com/watch?v=2_HFhdy5VMQ
# 65 https://www.youtube.com/watch?v=me-8hY5duGs
# 66 https://www.youtube.com/watch?v=pHL0z3Dz3VQ
# 67 https://www.youtube.com/watch?v=ZaS8s5OQK94
# 68 https://www.youtube.com/watch?v=HlhzyNvO-aY
# 69 https://www.youtube.com/watch?v=fH9OTUm8Syc
# 70 https://www.youtube.com/watch?v=vgFlKFaSJZE
# 71 https://www.youtube.com/watch?v=Tuwkf29xwKE
# 72 https://www.youtube.com/watch?v=K0wdd63Hhr4
# 73 https://www.youtube.com/watch?v=HEwu_wcFerA
# 74 https://www.youtube.com/watch?v=xF1jqmsdWRU
# 75 https://www.youtube.com/watch?v=EwzMYlDyqXI
# 76 https://www.youtube.com/watch?v=uAR-2i8DAZs
# 77 https://www.youtube.com/watch?v=4IiIf99kxw0
# 78 https://www.youtube.com/watch?v=Nz3qZW0Qegk
# 79 https://www.youtube.com/watch?v=49qjLMBgMsU
# 80 https://www.youtube.com/watch?v=bhZiuIV7oAU
# 82 https://www.youtube.com/watch?v=z35LfFNUXnY
# 83 https://www.youtube.com/watch?v=tkJqWmY6I2Q
# 84 https://www.youtube.com/watch?v=C1stWeuoPRM
# 87 https://www.youtube.com/watch?v=cFYvbxJtZdA
# 88 https://www.youtube.com/watch?v=c78O_hFnQuo
# 89 https://www.youtube.com/watch?v=LXN4IvtY-8A
# 90 https://www.youtube.com/watch?v=qLSNeuJ2n3I
# 91 https://www.youtube.com/watch?v=X02Z8j08n-w
# 93 https://www.youtube.com/watch?v=Vt-LE6bfs7k
# 94 https://www.youtube.com/watch?v=IX7k5BxBCrs
# 95 https://www.youtube.com/watch?v=oVF6g1XAnHU
# 97 https://www.youtube.com/watch?v=lQrRya3IH7U
# 98 https://www.youtube.com/watch?v=c9ccPMwUg-A
# 99 https://www.youtube.com/watch?v=eYHnoV84U-0
# 100 https://www.youtube.com/watch?v=M2tqUJRNTOQ
# 102 https://www.youtube.com/watch?v=2zX-rPvA-Po
# 103 https://www.youtube.com/watch?v=pNviU5hVVhY
# 104 https://www.youtube.com/watch?v=cpDsapq33K8
# 105 https://www.youtube.com/watch?v=6z5WnLc6jjo
# 106 https://www.youtube.com/watch?v=ouxJ1KiQj8M
# 107 https://www.youtube.com/watch?v=RWFC0VkItvk
# 108 https://www.youtube.com/watch?v=utgSl7RjtSU
# 110 https://www.youtube.com/watch?v=AA6DH2RFA6E
# 111 https://www.youtube.com/watch?v=loFOqBasqT0
# 112 https://www.youtube.com/watch?v=N3_BGW0P4V0
# 113 https://www.youtube.com/watch?v=inRNp5En-yw
# 115 https://www.youtube.com/watch?v=iZU13RGKVJ0
# 116 https://www.youtube.com/watch?v=qSnETGPpUKE
# 117 https://www.youtube.com/watch?v=r3dLt1Uf3qU
# 118 https://www.youtube.com/watch?v=HtA5U0j5ojs
# 119 https://www.youtube.com/watch?v=XuZ8u7LOAHI
# 120 https://www.youtube.com/watch?v=x44GmR3yoa8
# 121 https://www.youtube.com/watch?v=R2QpjAtRtF4
# 122 https://www.youtube.com/watch?v=gdibUjS76i0
# 123 https://www.youtube.com/watch?v=U7P0eyV_UeU
# 124 https://www.youtube.com/watch?v=5Ym1pEIAoTM
# 126 https://www.youtube.com/watch?v=wbWMWPwcZxs
# 127 https://www.youtube.com/watch?v=c6B7Btc-T0U
# 128 https://www.youtube.com/watch?v=oApbW1rVIys
# 129 https://www.youtube.com/watch?v=YPd2Io4-Qgw
# 130 https://www.youtube.com/watch?v=YZNfLpo14fo
# 131 https://www.youtube.com/watch?v=tZdUzN_40Ik
# 132 https://www.youtube.com/watch?v=h9MFT4J1-jQ
# 133 https://www.youtube.com/watch?v=jykzPNt5rMo
# 134 https://www.youtube.com/watch?v=9cCVVEdlaEw
# 135 https://www.youtube.com/watch?v=Ggf_sddOLmo
# 136 https://www.youtube.com/watch?v=Dc55nVrq43g
# 137 https://www.youtube.com/watch?v=kBJp881ghKY
# 138 https://www.youtube.com/watch?v=CoD0xEWp2vk
# 139 https://www.youtube.com/watch?v=Ak0tyiHCyw8
# 140 https://www.youtube.com/watch?v=TpBwqSytck4
# 141 https://www.youtube.com/watch?v=kxqBV9vIKf8
# 142 https://www.youtube.com/watch?v=g6Z6X4fZNkw
# 143 https://www.youtube.com/watch?v=Ucg5eg6qyNU
# 144 https://www.youtube.com/watch?v=0KE3k2VEJFY
# 145 https://www.youtube.com/watch?v=lDKh0cOnN9c
# 146 https://www.youtube.com/watch?v=12qKrBJQ9io
# 147 https://www.youtube.com/watch?v=mKVy1rCIRZo
# 148 https://www.youtube.com/watch?v=1ugAbImcwag
# 149 https://www.youtube.com/watch?v=XpuHdL4zky4
# 150 https://www.youtube.com/watch?v=HcfJ2KJ2ZBE
# 151 https://www.youtube.com/watch?v=5xL35Yy8-mA
# 152 https://www.youtube.com/watch?v=uaVh7eVONxE
# 153 https://www.youtube.com/watch?v=AobRh6qfcAM
# 154 https://www.youtube.com/watch?v=CeLT0WDAlYQ
# 155 https://www.youtube.com/watch?v=oHnn8DW05bM
# 156 https://www.youtube.com/watch?v=akHCzVVQ-aY
# 157 https://www.youtube.com/watch?v=RopYxHcTZXs
# 158 https://www.youtube.com/watch?v=DKFVft9sIB8
# 159 https://www.youtube.com/watch?v=9-W6nAFiSsA
# 160 https://www.youtube.com/watch?v=lt3tu4q6ljo
# 161 https://www.youtube.com/watch?v=DvcJcofOWUc
# 162 https://www.youtube.com/watch?v=xrBbpEaeKYA
# 163 https://www.youtube.com/watch?v=zWLuaWJoD44
# 165 https://www.youtube.com/watch?v=tdrCEHzTKj4
# 166 https://www.youtube.com/watch?v=vq-Kz0xlNQ8
# 167 https://www.youtube.com/watch?v=6cS4blKxDd8
# 168 https://www.youtube.com/watch?v=7lJ4ed3t94E
# 169 https://www.youtube.com/watch?v=5DPn9fqGDwQ
# 170 https://www.youtube.com/watch?v=wub5xuulQAU
# 172 https://www.youtube.com/watch?v=5pgZsFHXhlQ
# 173 https://www.youtube.com/watch?v=OmWWJKOsVUo
# 174 https://www.youtube.com/watch?v=tyhRBxReplw
# 175 https://www.youtube.com/watch?v=AimEUs3o4vw
# 177 https://www.youtube.com/watch?v=xAIOD5llBd4
# 178 https://www.youtube.com/watch?v=-YIC8aKAy-U
# 179 https://www.youtube.com/watch?v=vqO5hzILoy0
# 180 https://www.youtube.com/watch?v=iZt3dYZBYzg
# 181 https://www.youtube.com/watch?v=fD2j0vlAxpM
# 182 https://www.youtube.com/watch?v=yF2j-mrZeSQ
# 183 https://www.youtube.com/watch?v=4wDlfnCst7w
# 184 https://www.youtube.com/watch?v=7XeujBAn8OM
# 185 https://www.youtube.com/watch?v=ZLlcQLkVU9o
# 186 https://www.youtube.com/watch?v=UYnoOEuVr5g
# 187 https://www.youtube.com/watch?v=LX6xzJ5YYTE
# 189 https://www.youtube.com/watch?v=S6ZO9KUtboA
# 190 https://www.youtube.com/watch?v=fazD1bVYNmk
# 191 https://www.youtube.com/watch?v=BgEFLikSK1c
# 192 https://www.youtube.com/watch?v=-pFKwnFnHlQ
# 193 https://www.youtube.com/watch?v=aTkJcz1lk70
# 194 https://www.youtube.com/watch?v=3Gb-K2arwdg
# 195 https://www.youtube.com/watch?v=kxf48MPNbtU
# 196 https://www.youtube.com/watch?v=MBHbILkMud0
# 197 https://www.youtube.com/watch?v=lMf4MWSv9gA
# 198 https://www.youtube.com/watch?v=XO-v8_r-3sM
# 199 https://www.youtube.com/watch?v=fbV0YC-0f6g
# 200 https://www.youtube.com/watch?v=JHaz9cJTjHg
# 201 https://www.youtube.com/watch?v=7bwtILHGgvM
# 204 https://www.youtube.com/watch?v=s8nkjCy8KjA
# 205 https://www.youtube.com/watch?v=oZpGKZC3j50
# 206 https://www.youtube.com/watch?v=2XyIrAymef4
# 207 https://www.youtube.com/watch?v=GPEMRoQzGxM
# 208 https://www.youtube.com/watch?v=yBJDsWs4680
# 209 https://www.youtube.com/watch?v=b1UGaPolK1o
# 210 https://www.youtube.com/watch?v=NDwqxzyCrUs
# 211 https://www.youtube.com/watch?v=47xSPhUF7sE
# 212 https://www.youtube.com/watch?v=CY3ynKXyO9E
# 213 https://www.youtube.com/watch?v=ta-TMkYFYyM
# 214 https://www.youtube.com/watch?v=G3Boc6kVhr8
# 215 https://www.youtube.com/watch?v=wthzvpZngnQ
# 216 https://www.youtube.com/watch?v=Cxq_Tq5J49s
# 217 https://www.youtube.com/watch?v=M3ddaX1CiCM
# 218 https://www.youtube.com/watch?v=ncyzJQoo_f0
# 220 https://www.youtube.com/watch?v=w-J5R7NABpo
# 221 https://www.youtube.com/watch?v=Wdlwt42cFHw
# 222 https://www.youtube.com/watch?v=03ykVjRPdqM
# 223 https://www.youtube.com/watch?v=LGs5wpDjGRk
# 224 https://www.youtube.com/watch?v=vpHvY6sEoC0
# 225 https://www.youtube.com/watch?v=CzK38OUmYnQ
# 226 https://www.youtube.com/watch?v=3DNnDKiSbE0
# 227 https://www.youtube.com/watch?v=G-tklXG768M
# 228 https://www.youtube.com/watch?v=3vp1Ufz31O0
# 230 https://www.youtube.com/watch?v=Jlr03PVOlzI
# 231 https://www.youtube.com/watch?v=VW2zUry3dPw
# 232 https://www.youtube.com/watch?v=kGDumXLb6Vw
# 233 https://www.youtube.com/watch?v=L9_iSU4cLMY
# 234 https://www.youtube.com/watch?v=N2pn02BCd-c
# 235 https://www.youtube.com/watch?v=t_XEOVFgPaY
# 237 https://www.youtube.com/watch?v=JPqqd2gKs_4
# 239 https://www.youtube.com/watch?v=7CuINcrbS-g
# 240 https://www.youtube.com/watch?v=JXmFUxxjvgw
# 241 https://www.youtube.com/watch?v=PVDEa8OMl5I
# 242 https://www.youtube.com/watch?v=W8tXQFjQMm8
# 243 https://www.youtube.com/watch?v=alLKAxHFjSA
# 244 https://www.youtube.com/watch?v=VFQgNWGi7JU
# 245 https://www.youtube.com/watch?v=RRPmbuGMe_Y
# 246 https://www.youtube.com/watch?v=_FMokp6K-IY
# 247 https://www.youtube.com/watch?v=kQ2mxyqrCLk
# 248 https://www.youtube.com/watch?v=bpQhBudqxNw
# 249 https://www.youtube.com/watch?v=L4rJggnDCAo
# 250 https://www.youtube.com/watch?v=NSxa9rPoGy4
# 252 https://www.youtube.com/watch?v=vx2apIjemJI
# 253 https://www.youtube.com/watch?v=VV7Md7widQA
# 254 https://www.youtube.com/watch?v=g6NM5WeoJWg
# 255 https://www.youtube.com/watch?v=JoMMpVv17JU
# 256 https://www.youtube.com/watch?v=xGp2QkS-BT4
# 257 https://www.youtube.com/watch?v=WbWz-AjOBYk
# 258 https://www.youtube.com/watch?v=E2oeqFtmCh4
# 259 https://www.youtube.com/watch?v=DxP4aXDjWHw
# 260 https://www.youtube.com/watch?v=8xap9HFCDKE
# 261 https://www.youtube.com/watch?v=0mgXOcw3Tv4
# 262 https://www.youtube.com/watch?v=K7vbSckPOn8
# 263 https://www.youtube.com/watch?v=pYSWFQ-hXuQ
#
# Stack the information from the tests in a Pandas dataframe
#
# Write file to Excel on Google Drive
#  The location is: /Users/valentin/Google Drive/VideoSearch/video_test_exist_20170909.xlsx

# %%
###########
#
# Important about the process to check if a video still exists
#
###########

"""
I need to loop through all videoId from the list Bijan has sent to YouTube
Those that exist will contain a title in --> json_data['items'][0]['snippet']['title']
For the removed videos, I'll get an error

    Solution: 1) Download the JSON
              2) Test if a title from a video is available (try: break:).
              3) If available, assign 1 and record the title, otherwise record 0, and leave the title empty
              4) Create a field with the current date
              5) Write the information back to the XLS file with the video I sent to Bijan
                 Need to have three fields: video_available = 0 or 1
                                            title = available or not
                                            video_available_date = current date
              
"""

## If a video is missing, I'll get an error to any of the statements below, because there is no content
## This is what the JSON data is for a video that has been removed

## json_data
# {u'etag': u'"m2yskBQFythfE4irbTIeOgYYfBU/urwPl9nySjq-t0nA5xY8yy_6E3U"',
# u'items': [],
# u'kind': u'youtube#videoListResponse',
# u'pageInfo': {u'resultsPerPage': 1, u'totalResults': 1}}


# JSON of an available video
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=d_6hXZvYdj0&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4

# JSON of a removed video    
# https://www.googleapis.com/youtube/v3/videos?part=snippet%2CcontentDetails%2Cstatistics&id=mkohpSaQ4uw&key=AIzaSyDHXROE2Qt0NglgCmTnO8Y8cMikF5mD-m4


json_data['items'][0]['snippet']['title']
json_data['items'][0].keys()

# There is a dictionary inside the list. I need to extract the values from the dictionary!!
print(type(json_data['items']))
print(type(json_data['items'][0]))
